# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\karan\OneDrive\Desktop\MyWorld\data project\StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none        72.0           72.0           74.0
# 1               completed        69.0           90.0           88.0
# 2                    none        90.0           95.0           93.0
# 3                    none        47.0           57.0           44.0
# 4                    none        76.0           78.0           75.0
#
#     Avg. Score
# 0  72.66666667
# 1  82.33333333
# 2  92.66666667
# 3  49.33333333
# 4  76.33333333

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1001 non-null   float64
#  6   reading score                1001 non-null   float64
#  7   writing score                1001 non-null   float64
#  8   Avg. Score                   1002 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 70.6+ KB
# gender                         2
# race/ethnicity                 2
# parental level of education    2
# lunch                          2
# test preparation course        2
# ...

# %%
#new columns created
df['math score'] = pd.to_numeric(df['math score'], errors='coerce')
df['reading score'] = pd.to_numeric(df['reading score'], errors='coerce')
df['writing score'] = pd.to_numeric(df['writing score'], errors='coerce')

df['Total_score'] = df['math score'] + df['reading score'] + df['writing score']
df['Average_score'] = df['Total_score'] / 3

print(df['Total_score'])
# Out:
# 0       218.000
# 1       247.000
# 2       278.000
# 3       148.000
# 4       229.000
#          ...
# 997     195.000
# 998     223.000
# 999     249.000
# 1000        NaN
# 1001    203.312
# Name: Total_score, Length: 1002, dtype: float64

# %%
df.groupby('gender')[['math score','reading score','writing score']].mean().plot(kind='bar')
plt.title('Average score by gender')
plt.ylabel('Score')
plt.show()

# %%
sns.boxplot(x='test preparation course',y='Average_score',data=df)
plt.title('impact of Test prepartion on score')
plt.show()

# %%
sns.barplot(x='parental level of education',y='Average_score',data=df)
plt.xticks(rotation=45)
plt.title('Aversge score by parental Education')
plt.show()
